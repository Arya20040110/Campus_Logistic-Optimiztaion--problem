# %% [markdown]
# <a href="https://colab.research.google.com/github/Arya20040110/Campus_Logistic-Optimiztaion--problem/blob/main/micro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import io

data = """
facility_id,daily_demand,priority_level
MED_CENTER , 50, Low
ENGLISH_BUILDING, 25, high
SCIENCE_HALL, 20, medium
DORM_A, 24, low
DORM_B, 30,LOW
LIBRARY, 18, medium
STADIUM, 12, medium
COMM_CENTER, 15, MEDIUM
PUBLIC_SCHOOL, 16,MEDIUM
LOCAL_HOSPITAL, 60, high
"""
df = pd.read_csv(io.StringIO(data))
print(df)
# Out:
#         facility_id  daily_demand priority_level
# 0       MED_CENTER             50            Low
# 1  ENGLISH_BUILDING            25           high
# 2      SCIENCE_HALL            20         medium
# 3            DORM_A            24            low
# 4            DORM_B            30            LOW
# 5           LIBRARY            18         medium
# 6           STADIUM            12         medium
# 7       COMM_CENTER            15         MEDIUM
# 8     PUBLIC_SCHOOL            16         MEDIUM
# 9    LOCAL_HOSPITAL            60           high

# %%
import pandas as pd
import io

data = """
facility_id,facility_name,facility_type,latitude,longitude
MED_CENTER,Campus Medical Center,Hospital,40.8075,-73.9626
ENG_BUILDING,Engineering Building,Academic,40.81,-73.96
SCIENCE_HALL,Science Hall,Academic,40.805,-73.965
DORM_A,North Dormitory,Residential,40.812,-73.959
DORM_B,South Dormitory,Residential,40.803,-73.966
LIBRARY,Main Library,Academic,40.8085,-73.963
STADIUM,University Stadium,Recreational,40.804,-73.964
COMM_CENTER,Community Center,Community,40.806,-73.961
PUBLIC_SCHOOL,Local Public School,School,40.802,-73.967
LOCAL_HOSPITAL,Community Hospital,Hospital,40.809,-73.958
"""
df_facilities = pd.read_csv(io.StringIO(data))
print(df_facilities)
# Out:
#       facility_id          facility_name facility_type  latitude  longitude
# 0      MED_CENTER  Campus Medical Center      Hospital   40.8075   -73.9626
# 1    ENG_BUILDING   Engineering Building      Academic   40.8100   -73.9600
# 2    SCIENCE_HALL           Science Hall      Academic   40.8050   -73.9650
# 3          DORM_A        North Dormitory   Residential   40.8120   -73.9590
# 4          DORM_B        South Dormitory   Residential   40.8030   -73.9660
# 5         LIBRARY           Main Library      Academic   40.8085   -73.9630
# 6         STADIUM     University Stadium  Recreational   40.8040   -73.9640
# 7     COMM_CENTER       Community Center     Community   40.8060   -73.9610
# 8   PUBLIC_SCHOOL    Local Public School        School   40.8020   -73.9670
# 9  LOCAL_HOSPITAL     Community Hospital      Hospital   40.8090   -73.9580

# %%
import pandas as pd
import io

data = """
center_lat,center_lon,radius_km,total_area
40.8075,-73.9626,2.0,12.56
"""
df_area = pd.read_csv(io.StringIO(data))
print(df_area)
# Out:
#    center_lat  center_lon  radius_km  total_area
# 0     40.8075    -73.9626        2.0       12.56

# %%
import pandas as pd
import io

data = """
from_warehouse,to_facility,distance_km,cost_per_unit
WH_NORTH,MED_CENTER,0.56,3.83
WH_NORTH,ENG_BUILDING,0.35,3.53
WH_NORTH,SCIENCE_HALL,0.86,4.29
WH_NORTH,DORM_A,0.31,3.46
WH_NORTH,DORM_B,1.09,4.64
WH_NORTH,LIBRARY,0.45,3.67
WH_NORTH,STADIUM,0.95,4.43
WH_NORTH,COMM_CENTER,0.74,4.1
WH_NORTH,PUBLIC_SCHOOL,1.22,4.84
WH_NORTH,LOCAL_HOSPITAL,0.55,3.82
WH_SOUTH,MED_CENTER,0.56,3.83
WH_SOUTH,ENG_BUILDING,0.86,4.29
WH_SOUTH,SCIENCE_HALL,0.34,3.52
WH_SOUTH,DORM_A,1.1,4.65
WH_SOUTH,DORM_B,0.29,3.44
WH_SOUTH,LIBRARY,0.67,4.0
WH_SOUTH,STADIUM,0.2,3.31
WH_SOUTH,COMM_CENTER,0.41,3.62
WH_SOUTH,PUBLIC_SCHOOL,0.37,3.56
WH_SOUTH,LOCAL_HOSPITAL,0.82,4.23
WH_EAST,MED_CENTER,0.47,3.71
WH_EAST,ENG_BUILDING,0.38,3.56
WH_EAST,SCIENCE_HALL,0.73,4.09
WH_EAST,DORM_A,0.53,3.79
WH_EAST,DORM_B,0.91,4.36
WH_EAST,LIBRARY,0.52,3.78
WH_EAST,STADIUM,0.71,4.06
WH_EAST,COMM_CENTER,0.38,3.56
WH_EAST,PUBLIC_SCHOOL,1.04,4.56
WH_EAST,LOCAL_HOSPITAL,0.19,3.28
WH_WEST,MED_CENTER,0.45,3.68
WH_WEST,ENG_BUILDING,0.73,4.09
WH_WEST,SCIENCE_HALL,0.38,3.56
WH_WEST,DORM_A,0.91,4.36
WH_WEST,DORM_B,0.53,3.79
WH_WEST,LIBRARY,0.44,3.65
WH_WEST,STADIUM,0.51,3.77
WH_WEST,COMM_CENTER,0.61,3.92
WH_WEST,PUBLIC_SCHOOL,0.62,3.93
WH_WEST,LOCAL_HOSPITAL,0.86,4.29
WH_CENTRAL,MED_CENTER,0.0,3.0
WH_CENTRAL,ENG_BUILDING,0.35,3.53
WH_CENTRAL,SCIENCE_HALL,0.34,3.52
WH_CENTRAL,DORM_A,0.58,3.88
WH_CENTRAL,DORM_B,0.58,3.86
WH_CENTRAL,LIBRARY,0.12,3.17
WH_CENTRAL,STADIUM,0.41,3.61
WH_CENTRAL,COMM_CENTER,0.21,3.32
WH_CENTRAL,PUBLIC_SCHOOL,0.71,4.07
WH_CENTRAL,LOCAL_HOSPITAL,0.42,3.63
"""
df_distances = pd.read_csv(io.StringIO(data))
print(df_distances)
# Out:
#    from_warehouse     to_facility  distance_km  cost_per_unit
# 0        WH_NORTH      MED_CENTER         0.56           3.83
# 1        WH_NORTH    ENG_BUILDING         0.35           3.53
# 2        WH_NORTH    SCIENCE_HALL         0.86           4.29
# 3        WH_NORTH          DORM_A         0.31           3.46
# 4        WH_NORTH          DORM_B         1.09           4.64
# 5        WH_NORTH         LIBRARY         0.45           3.67
# 6        WH_NORTH         STADIUM         0.95           4.43
# 7        WH_NORTH     COMM_CENTER         0.74           4.10
# 8        WH_NORTH   PUBLIC_SCHOOL         1.22           4.84
# 9        WH_NORTH  LOCAL_HOSPITAL         0.55           3.82
# 10       WH_SOUTH      MED_CENTER         0.56           3.83
# 11       WH_SOUTH    ENG_BUILDING         0.86           4.29
# 12       WH_SOUTH    SCIENCE_HALL         0.34           3.52
# 13       WH_SOUTH          DORM_A         1.10           4.65
# ...

# %%
import pandas as pd
import io

data = """
warehouse_id,warehouse_name,latitude,longitude,capacity,construction_cost,operational_cost
WH_NORTH,North Campus Warehouse,40.8125,-73.9626,400,300000,800
WH_SOUTH,South Campus Warehouse,40.8025,-73.9626,350,280000,700
WH_EAST,East Gate Warehouse,40.8075,-73.957,450,320000,900
WH_WEST,West Gate Warehouse,40.8075,-73.968,300,250000,600
WH_CENTRAL,Central Storage,40.8075,-73.9626,500,350000,1000
"""
df_warehouses = pd.read_csv(io.StringIO(data))
print(df_warehouses)
# Out:
#   warehouse_id          warehouse_name  latitude  longitude  capacity  \
# 0     WH_NORTH  North Campus Warehouse   40.8125   -73.9626       400
# 1     WH_SOUTH  South Campus Warehouse   40.8025   -73.9626       350
# 2      WH_EAST     East Gate Warehouse   40.8075   -73.9570       450
# 3      WH_WEST     West Gate Warehouse   40.8075   -73.9680       300
# 4   WH_CENTRAL         Central Storage   40.8075   -73.9626       500
#
#    construction_cost  operational_cost
# 0             300000               800
# 1             280000               700
# 2             320000               900
# 3             250000               600
# 4             350000              1000

# %%
import pandas as pd
import pulp
import matplotlib.pyplot as plt
import os
import folium

# ==========================================
# 1. SETUP & DATA LOADING
# ==========================================
print("Loading data...")

# The dataframes are already loaded in previous cells, using them directly.
# demands_df -> df
# warehouses_df -> df_warehouses
# transport_df -> df_distances
# facilities_df -> df_facilities

# Parameters from Problem Statement
TARGET_FACILITIES = ['MED_CENTER', 'ENG_BUILDING', 'SCIENCE_HALL',
                     'DORM_A', 'DORM_B', 'LIBRARY']
TARGET_WAREHOUSES = ['WH_NORTH', 'WH_SOUTH', 'WH_EAST']

DAYS_PER_YEAR = 365
AMORTIZATION_YEARS = 10
BUDGET_LIMIT = 1500000

# ==========================================
# 2. DATA PRE-PROCESSING
# ==========================================
# Filter and Annualize Demand
df['facility_id'] = df['facility_id'].str.strip() # Clean facility_id column: remove trailing spaces
df['facility_id'] = df['facility_id'].replace('ENGLISH_BUILDING', 'ENG_BUILDING') # Standardize name
demands_subset = df[df['facility_id'].isin(TARGET_FACILITIES)].set_index('facility_id')
annual_demand = (demands_subset['daily_demand'] * DAYS_PER_YEAR).to_dict()

# Filter and Annualize Warehouse Data
warehouses_subset = df_warehouses[df_warehouses['warehouse_id'].isin(TARGET_WAREHOUSES)].set_index('warehouse_id')
annual_capacity = (warehouses_subset['capacity'] * DAYS_PER_YEAR).to_dict()

# Calculate Annualized Fixed Cost: (Construction / 10) + (Daily Op * 365)
annual_fixed_cost = {}
for wh_id, row in warehouses_subset.iterrows():
    cost = (row['construction_cost'] / AMORTIZATION_YEARS) + (row['operational_cost'] * DAYS_PER_YEAR)
    annual_fixed_cost[wh_id] = cost

# Filter Transportation Costs
transport_costs = {}
for _, row in df_distances.iterrows():
    if row['from_warehouse'] in TARGET_WAREHOUSES and row['to_facility'] in TARGET_FACILITIES:
        transport_costs[(row['from_warehouse'], row['to_facility'])] = row['cost_per_unit']

# ==========================================
# 3. OPTIMIZATION MODEL (PuLP)
# ==========================================
print("Solving optimization model...")
prob = pulp.LpProblem("Campus_City_Emergency_Distribution", pulp.LpMinimize)

# Decision Variables
# y[j]: Binary (1 if warehouse is Open, 0 if Closed)
y = pulp.LpVariable.dicts("Open", TARGET_WAREHOUSES, cat='Binary')

# x[j][i]: Continuous (Amount shipped from Warehouse j to Facility i)
x = pulp.LpVariable.dicts("Ship", (TARGET_WAREHOUSES, TARGET_FACILITIES), lowBound=0, cat='Continuous')

# Objective Function: Minimize Total Annual Cost
prob += (
    pulp.lpSum([annual_fixed_cost[j] * y[j] for j in TARGET_WAREHOUSES]) +
    pulp.lpSum([transport_costs[(j, i)] * x[j][i] for j in TARGET_WAREHOUSES for i in TARGET_FACILITIES])
), "Total_Annual_Cost"

# Constraints
# 1. Demand Satisfaction
for i in TARGET_FACILITIES:
    prob += pulp.lpSum([x[j][i] for j in TARGET_WAREHOUSES]) == annual_demand[i], f"Demand_{i}"

# 2. Capacity Constraints
for j in TARGET_WAREHOUSES:
    prob += pulp.lpSum([x[j][i] for i in TARGET_FACILITIES]) <= annual_capacity[j] * y[j], f"Capacity_{j}"

# 3. Select Exactly 2 Warehouses
prob += pulp.lpSum([y[j] for j in TARGET_WAREHOUSES]) == 2, "Select_2_Warehouses"

# 4. Budget Constraint
prob += (
    pulp.lpSum([annual_fixed_cost[j] * y[j] for j in TARGET_WAREHOUSES]) +
    pulp.lpSum([transport_costs[(j, i)] * x[j][i] for j in TARGET_WAREHOUSES for i in TARGET_FACILITIES])
) <= BUDGET_LIMIT, "Budget_Limit"

# Solve
prob.solve()

# ==========================================
# 4. REPORTING RESULTS
# ==========================================
print("\n" + "="*40)
print(f"OPTIMIZATION STATUS: {pulp.LpStatus[prob.status]}")
print("="*40)

if pulp.LpStatus[prob.status] != 'Optimal':
    print("Solution not found. Check constraints.")
    exit()

total_cost = pulp.value(prob.objective)
total_fixed = sum([annual_fixed_cost[j] * pulp.value(y[j]) for j in TARGET_WAREHOUSES])
total_transport = sum([transport_costs[(j, i)] * pulp.value(x[j][i]) for j in TARGET_WAREHOUSES for i in TARGET_FACILITIES])

print(f"\nFINANCIAL SUMMARY:")
print(f"Total Annual Cost:      ${total_cost:,.2f}")
print(f"  - Fixed Costs:        ${total_fixed:,.2f}")
print(f"  - Transport Costs:    ${total_transport:,.2f}")
print(f"Remaining Budget:       ${BUDGET_LIMIT - total_cost:,.2f}")

print("\nWAREHOUSE SELECTION:")
for j in TARGET_WAREHOUSES:
    if pulp.value(y[j]) > 0.5:
        used_capacity = sum([pulp.value(x[j][i]) for i in TARGET_FACILITIES])
        utilization = (used_capacity / annual_capacity[j]) * 100
        print(f"  [X] {j} (Utilization: {utilization:.1f}%) ({used_capacity:<10.0f} / {annual_capacity[j]:<10.0f})")
    else:
        print(f"  [ ] {j}")

print("\nDETAILED SHIPPING PLAN (Units/Year):")
print(f"{'Warehouse':<15} {'Facility':<20} {'Units':<10} {'Cost':<10}")
print("-" * 55)
for j in TARGET_WAREHOUSES:
    for i in TARGET_FACILITIES:
        val = pulp.value(x[j][i])
        if val > 0:
            cost = val * transport_costs[(j, i)]
            print(f"{j:<15} {i:<20} {val:<10.0f} ${cost:,.2f}")

# ==========================================
# 5. VISUALIZATION (Matplotlib)
# ==========================================
print("\nGenerating Matplotlib Network Map...")

# Filter coordinates
fac_coords = df_facilities[df_facilities['facility_id'].isin(TARGET_FACILITIES)].set_index('facility_id')
wh_coords = df_warehouses[df_warehouses['warehouse_id'].isin(TARGET_WAREHOUSES)].set_index('warehouse_id')

plt.figure(figsize=(12, 8))

# Plot Facilities
plt.scatter(fac_coords['longitude'], fac_coords['latitude'], c='blue', s=100, label='Facilities', zorder=3)
for idx, row in fac_coords.iterrows():
    plt.text(row['longitude'], row['latitude'] + 0.0005, idx, fontsize=8, ha='center')

# Plot Warehouses (Color by Selection)
for wh in TARGET_WAREHOUSES:
    lat, lon = wh_coords.loc[wh, 'latitude'], wh_coords.loc[wh, 'longitude']
    if pulp.value(y[wh]) > 0.5:
        plt.scatter(lon, lat, c='red', s=250, marker='s', edgecolors='black', zorder=4, label='Open Warehouse' if wh == TARGET_WAREHOUSES[0] else "")
        plt.text(lon, lat - 0.0005, wh, fontsize=10, fontweight='bold', ha='center')
    else:
        plt.scatter(lon, lat, c='gray', s=100, marker='x', zorder=2, label='Closed Warehouse' if wh == TARGET_WAREHOUSES[2] else "")

# Plot Flow Lines
flow_values = [pulp.value(x[j][i]) for j in TARGET_WAREHOUSES for i in TARGET_FACILITIES if pulp.value(x[j][i]) is not None]
max_flow = max(flow_values) if flow_values else 1 # Avoid error if no flow or all flows are zero, set to 1 for division

for j in TARGET_WAREHOUSES:
    for i in TARGET_FACILITIES:
        val = pulp.value(x[j][i])
        if val > 0:
            # Line width proportional to shipment size
            w_lon, w_lat = wh_coords.loc[j, 'longitude'], wh_coords.loc[j, 'latitude']
            f_lon, f_lat = fac_coords.loc[i, 'longitude'], fac_coords.loc[i, 'latitude']
            width = 1 + (val / max_flow) * 5
            plt.plot([w_lon, f_lon], [w_lat, f_lat], 'k--', linewidth=width, alpha=0.5, zorder=1)

plt.title(f'Optimal Supply Distribution Network (Total Cost: ${total_cost:,.0f})', fontsize=14)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True, linestyle=':', alpha=0.6)

# Handle duplicate labels in legend
handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys())

# Save and Show Matplotlib plot
plt.savefig('campus_distribution_map.png', dpi=300)
print("Matplotlib map saved as 'campus_distribution_map.png'.")
plt.show()

# ==========================================
# 6. VISUALIZATION (Folium)
# ==========================================
print("\nGenerating Folium Interactive Map...")

# Create a Folium map
center_lat = df_area['center_lat'].iloc[0]
center_lon = df_area['center_lon'].iloc[0]
m = folium.Map(location=[center_lat, center_lon], zoom_start=13)

# Add Facilities to map
for idx, row in fac_coords.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=f"<b>{idx}</b><br>Daily Demand: {demands_subset.loc[idx, 'daily_demand']}",
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(m)

# Add Warehouses to map
for wh in TARGET_WAREHOUSES:
    lat, lon = wh_coords.loc[wh, 'latitude'], wh_coords.loc[wh, 'longitude']
    if pulp.value(y[wh]) > 0.5:
        # Open warehouse
        folium.Marker(
            location=[lat, lon],
            popup=f"<b>{wh} (OPEN)</b><br>Capacity: {annual_capacity[wh]/DAYS_PER_YEAR} units/day",
            icon=folium.Icon(color='green', icon='home')
        ).add_to(m)
    else:
        # Closed warehouse
        folium.Marker(
            location=[lat, lon],
            popup=f"<b>{wh} (CLOSED)</b>",
            icon=folium.Icon(color='red', icon='remove')
        ).add_to(m)

# Add Flow Lines to map
flow_values = [pulp.value(x[j][i]) for j in TARGET_WAREHOUSES for i in TARGET_FACILITIES if pulp.value(x[j][i]) is not None]
max_flow = max(flow_values) if flow_values else 1

for j in TARGET_WAREHOUSES:
    for i in TARGET_FACILITIES:
        val = pulp.value(x[j][i])
        if val > 0:
            w_lat, w_lon = wh_coords.loc[j, 'latitude'], wh_coords.loc[j, 'longitude']
            f_lat, f_lon = fac_coords.loc[i, 'latitude'], fac_coords.loc[i, 'longitude']
            # Line thickness proportional to shipment size
            line_weight = 1 + (val / max_flow) * 5
            folium.PolyLine(
                locations=[(w_lat, w_lon), (f_lat, f_lon)],
                color='black',
                weight=line_weight,
                opacity=0.7,
                tooltip=f"Shipment from {j} to {i}: {val:.0f} units/year"
            ).add_to(m)

# Save and Show Folium map
map_filename = 'campus_distribution_map_folium.html'
m.save(map_filename)
print(f"Interactive map saved as '{map_filename}'.")
# Out:
# Loading data...
# Solving optimization model...
#
# ...
# OPTIMIZATION STATUS: Optimal
# ...
#
# FINANCIAL SUMMARY:
# Total Annual Cost:      $825,394.25
#   - Fixed Costs:        $605,500.00
#   - Transport Costs:    $219,894.25
# Remaining Budget:       $674,605.75
#
# WAREHOUSE SELECTION:
#   [X] WH_NORTH (Utilization: 29.2%) (42705      / 146000    )
#   [X] WH_SOUTH (Utilization: 14.3%) (18250      / 127750    )
#   [ ] WH_EAST
#
# DETAILED SHIPPING PLAN (Units/Year):
# Warehouse       Facility             Units      Cost
# -------------------------------------------------------
# WH_NORTH        MED_CENTER           18250      $69,897.50
# WH_NORTH        ENG_BUILDING         9125       $32,211.25
# WH_NORTH        DORM_A               8760       $30,309.60
# WH_NORTH        LIBRARY              6570       $24,111.90
# WH_SOUTH        SCIENCE_HALL         7300       $25,696.00
# WH_SOUTH        DORM_B               10950      $37,668.00
#
# Generating Matplotlib Network Map...
# ...

# %%
if 'df' in globals():
    print("'df' is defined.")
else:
    print("'df' is NOT defined.")
# Out:
# 'df' is defined.
